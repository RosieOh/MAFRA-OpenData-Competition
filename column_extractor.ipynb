# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
# seaborn 의 set 기능을 통해 폰트, 마이너스 폰트 설정, 스타일 설정을 합니다.

sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
# set matplotlib formats로 한글 폰트를 선명하게 해줍니다.

from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')
# Out:
# C:\Users\3balb\AppData\Local\Temp\ipykernel_9960\2061869597.py:5: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
# csv 파일을 불러들입니다.

df = pd.read_csv("./data/행정안전부_지역_재해위험지구.csv", encoding='utf-8')
df.head()
# Out:
#   DST_RSK_DSTRCT_MNG_NO DST_RSK_DSTRCT_NM DST_RSK_DSTRCT_GRD_CD  \
# 0            재해위험지구관리번호           재해위험지구명            재해위험지구등급코드
# 1          488502011013              청룡지구                     2
# 2          472102006001              사일지구                     2
# 3          472102006002             아랫들지구                     3
# 4          472102006003             중촌들지구                     3
#
#   DST_RSK_DSTRCT_TYPE_CD DST_RSK_DSTRCTCD DST_RSK_DSTRCT_RGN_CD  \
# 0             재해위험지구유형코드         재해위험지구코드            재해위험지구지역코드
# 1                    001              NaN            4885041000
# 2                    001              NaN            4721000000
# 3                    001              NaN            4721000000
# 4                    002              NaN            4721000000
#
#   DST_RSK_DSTRCT_HONU MAO_CD MAOF_NM FCLT_NM  ... ATCH_FILE_ID_5 LINK_STTS  \
# 0            재해위험지구번지   부처코드     부처명     시설명  ...       첨부파일아이디5      연계상태
# ...

# %%
import pandas as pd

# Extract the column names and the first row
column_names = df.columns.tolist()
first_row = df.iloc[0].tolist()

# Create a new DataFrame with the desired structure
new_df = pd.DataFrame({
    'ENG_NAME': column_names,
    'KOR_NAME': first_row
})

# Display the new DataFrame
print(new_df)

# Save the new DataFrame to a CSV file
new_df.to_csv('data/컬럼명세서.csv', index=False)
# Out:
#                   ENG_NAME    KOR_NAME
# 0    DST_RSK_DSTRCT_MNG_NO  재해위험지구관리번호
# 1        DST_RSK_DSTRCT_NM     재해위험지구명
# 2    DST_RSK_DSTRCT_GRD_CD  재해위험지구등급코드
# 3   DST_RSK_DSTRCT_TYPE_CD  재해위험지구유형코드
# 4         DST_RSK_DSTRCTCD    재해위험지구코드
# ..                     ...         ...
# 88                 LINKLOG        연계로그
# 89            LINK_TRNS_ID   연계트랜잭션아이디
# 90             MAO_CD_BKUP    부처코드_BAK
# 91           TMPR_COL_BKUP    임시컬럼_BAK
# 92            STDG_CD_BKUP   법정동코드_BAK
#
# [93 rows x 2 columns]
