# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('retina')
# Out:
# C:\Users\3balb\AppData\Local\Temp\ipykernel_13088\1386094027.py:3: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina')

# %%
df = pd.read_csv("./data/crisis_address(utf-8).csv", encoding='utf-8')
df.head()
# Out:
#   DST_RSK_DSTRCT_NM  DST_RSK_DSTRCT_GRD_CD  DST_RSK_DSTRCT_TYPE_CD  \
# 0              청룡지구                      2                       1
# 1             아랫들지구                      3                       1
# 2             중촌들지구                      3                       2
# 3              피골지구                      1                       1
# 4              죽계지구                      3                       1
#
#   DST_RSK_DSTRCTCD  DST_RSK_DSTRCT_RGN_CD FCLT_NM  DSGN_YMD     DSGN_RSN  \
# 0              NaN             4885041000    청룡지구  20100520       상습침수지역
# 1              NaN             4721000000   아랫들지구  20060228  재해위험지구 지정관리
# 2              NaN             4721000000   중촌들지구  20060228  재해위험지구 지정관리
# 3              NaN             4721000000    피골지구  20060228  재해위험지구 지정관리
# 4              NaN             4721000000    죽계지구  20060302  재해위험지구 지정관리
#
#                                         RSK_FACTR_CN  DSGN_AREA       STDG_CD  \
# ...

# %%
df.columns
# Out:
# Index(['DST_RSK_DSTRCT_NM', 'DST_RSK_DSTRCT_GRD_CD', 'DST_RSK_DSTRCT_TYPE_CD',
#        'DST_RSK_DSTRCTCD', 'DST_RSK_DSTRCT_RGN_CD', 'FCLT_NM', 'DSGN_YMD',
#        'DSGN_RSN', 'RSK_FACTR_CN', 'DSGN_AREA', 'STDG_CD', 'DADDR',
#        'RONA_DADDR', 'x', 'y'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['DST_RSK_DSTRCT_NM', 'DST_RSK_DSTRCT_GRD_CD', 'DST_RSK_DSTRCT_TYPE_CD',
#        'DST_RSK_DSTRCTCD', 'DST_RSK_DSTRCT_RGN_CD', 'FCLT_NM', 'DSGN_YMD',
#        'DSGN_RSN', 'RSK_FACTR_CN', 'DSGN_AREA', 'STDG_CD', 'DADDR',
#        'RONA_DADDR', 'x', 'y'],
#       dtype='object')

# %%
print(df.shape)
df = df.drop(['작성자명',
       '작성자소속직급내용', '확인자명',
       '확인자소속직급내용', '시설관리기관명',
       '시설관리기관전화번호', '관리책임자명',
       '관리책임자소속직급내용',
       '관리책임자사무실전화번호',
       '관리책임자자택전화번호',
       '관리책임자휴대전화번호', '관리주민명',
       '관리주민직급명', '관리주민사무실전화번호',
       '관리주민자택전화번호', '관리주민휴대전화번호',
       '연락처비고', '최종수정일시', '최종수정자아이디',
       '신청여부', '신청연도', '신청일자',
       '협의일자', '확인일자', '결과통보일자', '중앙확인자내용',
       '비용편익값','사용여부', '복구계획버전값',
       '첨부파일아이디1',
       '첨부파일아이디2', '첨부파일아이디3',
       '첨부파일아이디4', '첨부파일아이디5',
       '연계상태', '연계처리유형', '연계처리시간',
       '연계메시지아이디', '연계로그', '연계트랜잭션아이디',
       '부처코드_BAK', '임시컬럼_BAK'], axis=1)

print(df.shape)
# Out:
# (100, 93)
# (100, 51)

# %%
df.columns
# Out:
# Index(['재해위험지구관리번호', '재해위험지구명', '재해위험지구등급코드', '재해위험지구유형코드', '재해위험지구코드',
#        '재해위험지구지역코드', '재해위험지구번지', '부처코드', '부처명', '시설명', '시설물등급코드', '시설물등급명',
#        '재해수계코드', '수계명', '지정일자', '지정사유', '해제일자', '해제사유', '피해주기', '피해일강우량',
#        '피해시간강우량', '위험요인내용', '추진사항코드', '지정면적', '지정연도', '고시일자', '중앙확인자명',
#        '결과구분자', '거주세대수', '거주인원수수', '기본계획명', '수립일자', '행위제한조례구분자', '제정일자',
#        '사망자수', '부상자수', '피해이력지수', '정책값', '지속값', '준비값', '기본계획여부', '산주소여부', '주지번',
#        '부지번', '상세주소', '도로명코드', '도로명상세주소', '법정동코드', '시설구분코드', '시설등급코드',
#        '법정동코드_BAK'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 51 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   재해위험지구관리번호  100 non-null    object
#  1   재해위험지구명     100 non-null    object
#  2   재해위험지구등급코드  99 non-null     object
#  3   재해위험지구유형코드  100 non-null    object
#  4   재해위험지구코드    45 non-null     object
#  5   재해위험지구지역코드  100 non-null    object
#  6   재해위험지구번지    23 non-null     object
#  7   부처코드        52 non-null     object
#  8   부처명         52 non-null     object
#  9   시설명         100 non-null    object
#  10  시설물등급코드     100 non-null    object
#  11  시설물등급명      99 non-null     object
#  12  재해수계코드      81 non-null     object
#  13  수계명         62 non-null     object
#  14  지정일자        100 non-null    object
#  15  지정사유        100 non-null    object
#  16  해제일자        73 non-null     object
#  17  해제사유        57 non-null     object
#  18  피해주기        78 non-null     object
# ...

# %%
plt.figure(figsize=(10,12))
df.isnull().sum().plot(kind='barh')
# Out:
# <Axes: >

# %%
print(df.shape)
df = df.drop(['재해위험지구지역코드', '부처코드', '부처명', '시설명',
       '지정연도', '고시일자', '중앙확인자명',
       '결과구분자', '거주세대수', '거주인원수수', '기본계획명',
       '도로명코드', '시설구분코드', '시설등급코드'], axis=1)

print(df.shape)
# Out:
# (100, 51)
# (100, 37)

# %%
df = df.to_csv('new_crisis_sheet.csv', sep=',', encoding='utf-8-sig', index=False, na_rep='NaN')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 1 to 100
# Data columns (total 37 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   재해위험지구관리번호  100 non-null    object
#  1   재해위험지구명     100 non-null    object
#  2   재해위험지구등급코드  99 non-null     object
#  3   재해위험지구유형코드  100 non-null    object
#  4   재해위험지구코드    45 non-null     object
#  5   재해위험지구번지    23 non-null     object
#  6   시설물등급코드     100 non-null    object
#  7   시설물등급명      99 non-null     object
#  8   재해수계코드      81 non-null     object
#  9   수계명         62 non-null     object
#  10  지정일자        100 non-null    object
#  11  지정사유        100 non-null    object
#  12  해제일자        73 non-null     object
#  13  해제사유        57 non-null     object
#  14  피해주기        78 non-null     object
#  15  피해일강우량      78 non-null     object
#  16  피해시간강우량     78 non-null     object
#  17  위험요인내용      100 non-null    object
#  18  추진사항코드      100 non-null    object
# ...

# %%
df[['산주소여부', '도로명상세주소', '법정동코드', '법정동코드_BAK']].head(10)
# Out:
#    산주소여부                    도로명상세주소       법정동코드   법정동코드_BAK
# 1      0          [지점번호:라라35898709]  4885041021  4885041021
# 2      0                        NaN  4721011100  4721010400
# 3      0                        NaN  4721037022  4721035000
# 4      0                        NaN  4721037024  4721037000
# 5      0  경상북도 영주시 단산면 옥대로  23-6     4721038025  4721038025
# 6      0                        NaN  4721011300  4721010500
# 7      0                        NaN  4721034022  4721034022
# 8      0                        NaN  4721010400  4721010400
# 9      0                        NaN  4721037022  4721037027
# 10     0                        NaN  4721033023  4721033023

# %%
df['상세주소'][df['상세주소'].isnull() == False].head(10)
# Out:
# 41
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# 51
# 54
# Name: 상세주소, dtype: object

# %%
new_ad_sample = df['도로명상세주소'][df['도로명상세주소'].isnull() == False]

# %%
new_ad_sample[new_ad_sample.str.contains('지점') == True]
# Out:
# 1      [지점번호:라라35898709]
# 11     [지점번호:라사86920935]
# 16     [지점번호:다바72272434]
# 26     [지점번호:다아92672789]
# 29     [지점번호:다라33358890]
# 31     [지점번호:라사99733196]
# 32     [지점번호:마사04132470]
# 33     [지점번호:마마81547189]
# 38     [지점번호:라마89136465]
# 42     [지점번호:라사20708713]
# 45     [지점번호:라사20498819]
# 51     [지점번호:라사26509321]
# 54     [지점번호:라사53895128]
# 56     [지점번호:마사36770455]
# 59     [지점번호:마사39790183]
# 60     [지점번호:마사32540958]
# 61     [지점번호:마사31630722]
# 62     [지점번호:마사32760976]
# 65     [지점번호:라사53214499]
# 67     [지점번호:라사42115108]
# 68     [지점번호:라사46735076]
# 69     [지점번호:라사56755342]
# 70     [지점번호:라사55885184]
# 73     [지점번호:마라39967801]
# 74     [지점번호:다사52674748]
# 78     [지점번호:다사54244249]
# 81     [지점번호:다사59054251]
# 86     [지점번호:다사42805086]
# 87     [지점번호:다사42834796]
# 88     [지점번호:마라37737577]
# 90     [지점번호:마라45598278]
# 92     [지점번호:라사37216861]
# 95     [지점번호:라사37596679]
# 96     [지점번호:라사47478441]
# 98     [지점번호:라사58307412]
# 99     [지점번호:라사22966548]
# ...
