# %% [markdown]
# ## Streamlit launch

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/crisis_address(utf-8).csv", encoding='utf-8')
df.head()
# Out:
#   DST_RSK_DSTRCT_NM  DST_RSK_DSTRCT_GRD_CD  DST_RSK_DSTRCT_TYPE_CD  \
# 0              청룡지구                      2                       1
# 1             아랫들지구                      3                       1
# 2             중촌들지구                      3                       2
# 3              피골지구                      1                       1
# 4              죽계지구                      3                       1
#
#   DST_RSK_DSTRCTCD  DST_RSK_DSTRCT_RGN_CD FCLT_NM  DSGN_YMD     DSGN_RSN  \
# 0              NaN             4885041000    청룡지구  20100520       상습침수지역
# 1              NaN             4721000000   아랫들지구  20060228  재해위험지구 지정관리
# 2              NaN             4721000000   중촌들지구  20060228  재해위험지구 지정관리
# 3              NaN             4721000000    피골지구  20060228  재해위험지구 지정관리
# 4              NaN             4721000000    죽계지구  20060302  재해위험지구 지정관리
#
#                                         RSK_FACTR_CN  DSGN_AREA       STDG_CD  \
# 0                                             상습침수지역   450000.0  4.885041e+09
# 1   제방붕괴 우려\r\n- 죽계지구 하천재해예방사업(준공예정일 : '23. 12. 17.)   140000.0  4.721037e+09
# 2  세굴로 인한 제방붕괴 우려\r\n- 죽계2지구 하천재해예방사업(준공예정일 : '23...   100000.0  4.721037e+09
# 3        침수위험\r\n- 죽계지구 하천재해예방사업(준공일 : '19. 12. 16.)    60000.0  4.721011e+09
# 4      침수위험\r\n- 죽계지구 하천재해예방사업(준공예정일 : '23. 12. 17.)   720000.0  4.721037e+09
#
#   DADDR          RONA_DADDR   x   y
# 0   NaN   [지점번호:라라35898709] NaN NaN
# 1   NaN                 NaN NaN NaN
# 2   NaN                 NaN NaN NaN
# 3   NaN                 NaN NaN NaN
# 4   NaN                 NaN NaN NaN

# %%
import folium
import pandas as pd
import requests

# Define a dictionary to map 'DST_RSK_DSTRCT_TYPE_CD' values to colors
color_map = {
    1: 'blue',
    2: 'purple',
    3: 'gray',
    4: 'orange',
    5: 'green',
    6: 'darkblue'
}

m = folium.Map(location=[df['y'].mean(), df['x'].mean()], zoom_start=8)

for i, row in df.iterrows():
    if pd.notnull(row['y']) and pd.notnull(row['x']) and pd.notnull(row['DSGN_AREA']):
        # Create the popup content with additional data
        popup_content = f"""
        <b>재해위험지구관리번호:</b> {row['DST_RSK_DSTRCT_NM']}<br>
        <b>재해위험지구등급코드:</b> {row['DST_RSK_DSTRCT_GRD_CD']}<br>
        <b>재해위험지구유형코드:</b> {row['DST_RSK_DSTRCT_TYPE_CD']}<br>
        <b>재해위험지구코드:</b> {row['DST_RSK_DSTRCTCD']}<br>
        <b>재해위험지구지역코드:</b> {row['DST_RSK_DSTRCT_RGN_CD']}<br>
        <b>시설명:</b> {row['FCLT_NM']}<br>
        <b>지정일자:</b> {row['DSGN_YMD']}<br>
        <b>지정사유:</b> {row['DSGN_RSN']}
        """
        popup = folium.Popup(popup_content, max_width=300)
        
        radius = (row['DSGN_AREA'] ** 0.5)
        color = color_map.get(row['DST_RSK_DSTRCT_TYPE_CD'], 'red')  # Default to 'red' if type code is not in color_map
        
        folium.Circle(
            location=[row['y'], row['x']],
            radius=radius,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.5,
            popup=popup
        ).add_to(m)

# Your REST API key for Kakao API
rest_api_key = 'bf0070cbed9ecd623aeead721c91397b'

# Function to get latitude and longitude from an address
def lat_long(address):
    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address
    headers = {"Authorization": "KakaoAK " + rest_api_key}
    try:
        response = requests.get(url, headers=headers)
        json_result = response.json()
        address_xy = json_result['documents'][0]['address']
        return float(address_xy['x']), float(address_xy['y'])
    except Exception as e:
        print(e)
        return None, None

# Function to mark an address on the map
def mark_address_on_map(address, folium_map):
    x, y = lat_long(address)
    if x is None or y is None:
        print("Failed to get coordinates for the address.")
        return

    folium.Marker([y, x], popup=address).add_to(folium_map)
    print("Address marker has been added to the map.")

# Example address to locate
address = '서울특별시 종로구 세종대로 209'
mark_address_on_map(address, m)

# Save the map with circles and the address marker
m.save('./data/map_with_scaled_circles.html')
# Out:
# Address marker has been added to the map.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c9efb6d6a5bcaa12ca48e05bae851a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c9efb6d6a5bcaa12ca48e05bae851a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c9efb6d6a5bcaa12ca48e05bae851a0 = L.map(
#                 &quot;map_7c9efb6d6a5bcaa12ca48e05bae851a0&quot;,
#                 {
#                     center: [35.73844946354, 127.52802346454529],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a500a360ed156014f1991abeab05ec3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a500a360ed156014f1991abeab05ec3.addTo(map_7c9efb6d6a5bcaa12ca48e05bae851a0);
#
#
#             var circle_8aed65b8985444671aa8b8907fcd8b82 = L.circle(
#                 [35.3980165032667, 127.333663944732],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 331.66247903554, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c9efb6d6a5bcaa12ca48e05bae851a0);
#
#
#         var popup_3b13a058d642eee7a77c835072ef14a6 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_1a787e791a31994cdfe2bb1bc099a019 = $(`&lt;div id=&quot;html_1a787e791a31994cdfe2bb1bc099a019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;재해위험지구관리번호:&lt;/b&gt; 정송지구&lt;br&gt;         &lt;b&gt;재해위험지구등급코드:&lt;/b&gt; 2&lt;br&gt;         &lt;b&gt;재해위험지구유형코드:&lt;/b&gt; 1&lt;br&gt;         &lt;b&gt;재해위험지구코드:&lt;/b&gt; nan&lt;br&gt;         &lt;b&gt;재해위험지구지역코드:&lt;/b&gt; 5219034000&lt;br&gt;         &lt;b&gt;시설명:&lt;/b&gt; 옥률천&lt;br&gt;         &lt;b&gt;지정일자:&lt;/b&gt; 20150202&lt;br&gt;         &lt;b&gt;지정사유:&lt;/b&gt; 내수배제불량 및 관로 통수단면부족         &lt;/div&gt;`)[0];
#                 popup_3b13a058d642eee7a77c835072ef14a6.setContent(html_1a787e791a31994cdfe2bb1bc099a019);
#
#
#
#         circle_8aed65b8985444671aa8b8907fcd8b82.bindPopup(popup_3b13a058d642eee7a77c835072ef14a6)
#         ;
#
#
#
#
#             var circle_69662d7a8d8a845b8703797a08b62562 = L.circle(
#                 [37.6014567802962, 126.964214527387],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 179.66079149330272, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c9efb6d6a5bcaa12ca48e05bae851a0);
#
#
#         var popup_2976dc7faa48064190081bd94421e70b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_75ff0181a5ec5f629c7df83faba40f3a = $(`&lt;div id=&quot;html_75ff0181a5ec5f629c7df83faba40f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;재해위험지구관리번호:&lt;/b&gt; 신영동&lt;br&gt;         &lt;b&gt;재해위험지구등급코드:&lt;/b&gt; 2&lt;br&gt;         &lt;b&gt;재해위험지구유형코드:&lt;/b&gt; 2&lt;br&gt;         &lt;b&gt;재해위험지구코드:&lt;/b&gt; 사면의붕괴&lt;br&gt;         &lt;b&gt;재해위험지구지역코드:&lt;/b&gt; 1111000000&lt;br&gt;         &lt;b&gt;시설명:&lt;/b&gt; 급경사지&lt;br&gt;         &lt;b&gt;지정일자:&lt;/b&gt; 20120517&lt;br&gt;         &lt;b&gt;지정사유:&lt;/b&gt; 사면의 붕괴위험         &lt;/div&gt;`)[0];
#                 popup_2976dc7faa48064190081bd94421e70b.setContent(html_75ff0181a5ec5f629c7df83faba40f3a);
#
#
#
#         circle_69662d7a8d8a845b8703797a08b62562.bindPopup(popup_2976dc7faa48064190081bd94421e70b)
#         ;
#
#
#
#
#             var circle_c42ab0a5559ac27c13a5d01f25ded1c6 = L.circle(
#                 [37.4941785557295, 126.99330663182],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2031.2557692225762, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7c9efb6d6a5bcaa12ca48e05bae851a0);
#
#
#         var popup_263721739c84f657f9e1927c11dd516e = L.popup({&quot;maxWidth&quot;: 300});
